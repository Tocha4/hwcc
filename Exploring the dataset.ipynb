# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %ls
# Out:
# Exploring the dataset.ipynb  sample_submission.csv  train/
# features/                    test/                  train.csv

# %%
df = pd.read_csv('train.csv')
df.head(); df.shape
# Out:
#           Image         Id
# 0  00022e1a.jpg  w_e15442c
# 1  000466c4.jpg  w_1287fbc
# 2  00087b01.jpg  w_da2efe0
# 3  001296d5.jpg  w_19e5482
# 4  0014cfdf.jpg  w_f22f3e3
# (9850, 2)

# %%
desc = df.describe()
desc
hist = df.Id.value_counts()
hist.describe()
# Out:
#                Image         Id
# count           9850       9850
# unique          9850       4251
# top     9f773b40.jpg  new_whale
# freq               1        810
# count    4251.000000
# mean        2.317102
# std        12.586066
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       810.000000
# Name: Id, dtype: float64

# %%
hist.plot()
plt.ylim([0,50])
hist.sum()
# Out:
# (0, 50)
# 9850

# %%
fig = plt.figure(figsize=(14, 9))
for n,i in enumerate(df.head(10).Image):
    img = cv2.imread('./train/'+i)
    a = plt.subplot(2,5,n+1)
    b = plt.imshow(img)

# %% [markdown]
# As you can see, the images have different size and color range (gray or three color chanels)
